# %%
from keras.models import load_model
from Pyramid import Pyramid

import numpy as np
from PIL import Image
import glob
import os

from model import CustomModel

threshold = 0.95
# Out:
# Using TensorFlow backend.

# %%
b = Pyramid(load_model('first_hard_iteration.nn'), threshold=threshold)
b.add_false_positive_to_negative_db("start_deep/added_images", strides=(18, 18))
# Out:
# start_deep/added_images/york_minster_cathedral_ceiling.jpg
# start_deep/added_images/Rattlesnake Ledge.jpg
# /usr/local/lib/python3.5/dist-packages/PIL/Image.py:2274: DecompressionBombWarning: Image size (206372352 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   DecompressionBombWarning)
# start_deep/added_images/autumn_in_the_blue_mountains_by_stevecampbell.jpg
# start_deep/added_images/glasgow_city_chamber.jpg
# number of analyzed :  152723

# %%
#model = CustomModel()
#model.model_to_train = load_model('first_hard_iteration.nn')
model.train()
# Out:
# Processed 0 of 1400
# Processed 250 of 1400
# Processed 500 of 1400
# Processed 750 of 1400
# Processed 1000 of 1400
# Processed 1250 of 1400
# Train on 1260 samples, validate on 140 samples
# Epoch 1/25
# 1260/1260 [==============================] - 1s - loss: 0.2710 - acc: 0.9016 - val_loss: 0.3150 - val_acc: 0.8714
# Epoch 2/25
# 1260/1260 [==============================] - 1s - loss: 0.2413 - acc: 0.9024 - val_loss: 0.1977 - val_acc: 0.9143
# Epoch 3/25
# 1260/1260 [==============================] - 1s - loss: 0.2125 - acc: 0.9206 - val_loss: 0.1771 - val_acc: 0.9429
# Epoch 4/25
# 1260/1260 [==============================] - 1s - loss: 0.1867 - acc: 0.9270 - val_loss: 0.2863 - val_acc: 0.8786
# Epoch 5/25
# 1260/1260 [==============================] - 1s - loss: 0.1936 - acc: 0.9254 - val_loss: 0.1964 - val_acc: 0.9286
# Epoch 6/25
# 1260/1260 [==============================] - 1s - loss: 0.1540 - acc: 0.9373 - val_loss: 0.1315 - val_acc: 0.9500
# Epoch 7/25
# ...

# %%
i = 0
model = load_model('first_hard_iteration.nn')
for path in glob.iglob('/home/francois/Documents/tmp/test_image_crop/*'):
    img = Image.open(path).convert('L')
    img = np.asarray(img)
    prediction = model.predict(np.expand_dims(np.expand_dims(img, axis=0), axis=3))
    if (prediction[0, 1] < threshold).any():
        print(path)
        os.remove(path)
        i += 1
        
print(i)
# Out:
# /home/francois/Documents/tmp/test_image_crop/IMG_C1_74_32.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C1_101_39.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C0_36_18.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C3_54_35.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C0_14_1.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C3_9_22.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C1_347_34.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C0_59_45.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C0_27_10.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C0_19_9.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C1_329_39.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C0_86_30.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C0_19_12.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C3_75_23.png
# /home/francois/Documents/tmp/test_image_crop/IMG_C1_137_46.png
# ...

# %%
figure()
x=list(range(0,100))
y=list(map(lambda x: 2*x, x))
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()

# %%
model = Sequential()
model.add(I)

# %%
from PIL import Image
import numpy as np

# %%
t = Image.open('tete.pgm').convert('L')

# %%
mod = load_model('first_launch.nn')

# %%
mod.predict(np.expand_dims(np.expand_dims(np.asarray(t), axis=0), axis=3))

# %%
for path in glob.iglob('/home/francois/Documents/INSA/5IF/DEEP/start_deep/train_images/0_ter/*'):
    with open('hard_neg_2_iter.txt', 'a+') as f:
        f.write('0_ter/{}'.format(path.split('/')[-1]))
        f.write(' 0')
        f.write('\n')

# %%
model.model_to_train.save('second_hard_iteration_from_scratch.nn')

# %%
pyr = Pyramid(load_model('second_hard_iteration_from_scratch.nn'), threshold=0.99)

# %%
pyr.test_pyramide('photo_famille.jpeg')

# %%
pyr_1 = Pyramid(load_model('first_hard_iteration.nn'))

# %%
pyr_1.test_pyramide('photo_famille.jpeg')
